# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('../../../../results/PFPGrowth_stats.csv')
df1
# Out:
#    time(ms)                               intable  minsize  minsup  \
# 0    293507  trajectory.hermopoulis_standard1_200       10      20
# 1    970417  trajectory.hermopoulis_standard1_200       10      19
# 2   2697742  trajectory.hermopoulis_standard1_200       10      18
# 3   7219749  trajectory.hermopoulis_standard1_200       10      17
# 4   9600000  trajectory.hermopoulis_standard1_200       10      16
#
#     nitemsets  repfreq    limit  nexecutors  ncores maxram timescale  bint  \
# 0   240828256        1  1000000          10       2     8g  absolute    60
# 1   638572748        1  1000000          10       2     8g  absolute    60
# 2  1819299840        1  1000000          10       2     8g  absolute    60
# 3  5665424404        1  1000000          10       2     8g  absolute    60
# 4  5665424404        1  1000000          10       2     8g  absolute    60
#
#    epst  bins  epss  semf
# 0   inf    19   inf   NaN
# 1   inf    19   inf   NaN
# 2   inf    19   inf   NaN
# ...

# %%
df2 = pd.read_csv('../../../../results/CTM_stats.csv')
df2
# Out:
#      time(ms)  brdneighborhoodbytes  brdtrajincellbytes  ntransactions  \
# 0      259008                     0             6341186            359
# 1       64482                     0             1413250             60
# 2      265460                     0             6341186            359
# 3       44797                  1496             1413250             60
# 4      423450                     0             6341684            360
# ..        ...                   ...                 ...            ...
# 107      6119                 12420              174160            126
# 108    146928                192966              427258            513
# 109      5318                  3150              281340            150
# 110     20009                  5420              267468            116
# 111      3087                  3150              281340            150
#
#                              intable  minsize  minsup  nitemsets  storagethr  \
# ...

# %%
[x for x in df1.columns if x not in ["time(ms)", "semf", "nitemsets"]]
# Out:
# ['intable',
#  'minsize',
#  'minsup',
#  'repfreq',
#  'limit',
#  'nexecutors',
#  'ncores',
#  'maxram',
#  'timescale',
#  'bint',
#  'epst',
#  'bins',
#  'epss']

# %%
df3 = df1.merge(df2, on=[x for x in df1.columns if x in ['epss', 'bins', 'epst', 'bint', 'maxram', 'ncores', 'intable', 'minsize', 'minsup', 'repfreq',  'limit', 'nexecutors',]])
df3
# Out:
#    time(ms)_x                               intable  minsize  minsup  \
# 0      293507  trajectory.hermopoulis_standard1_200       10      20
# 1      970417  trajectory.hermopoulis_standard1_200       10      19
# 2     2697742  trajectory.hermopoulis_standard1_200       10      18
# 3     7219749  trajectory.hermopoulis_standard1_200       10      17
# 4     9600000  trajectory.hermopoulis_standard1_200       10      16
#
#    nitemsets_x  repfreq    limit  nexecutors  ncores maxram  ...  \
# 0    240828256        1  1000000          10       2     8g  ...
# 1    638572748        1  1000000          10       2     8g  ...
# 2   1819299840        1  1000000          10       2     8g  ...
# 3   5665424404        1  1000000          10       2     8g  ...
# 4   5665424404        1  1000000          10       2     8g  ...
#
#   ntransactions  nitemsets_y  storagethr    timescale_y  exploredpatterns  \
# 0           536          853     1000000  AbsoluteScale           5018227
# ...

# %%
df3.columns
# Out:
# Index(['time(ms)_x', 'intable', 'minsize', 'minsup', 'nitemsets_x', 'repfreq',
#        'limit', 'nexecutors', 'ncores', 'maxram', 'timescale_x', 'bint',
#        'epst', 'bins', 'epss', 'semf_x', 'time(ms)_y', 'brdneighborhoodbytes',
#        'brdtrajincellbytes', 'ntransactions', 'nitemsets_y', 'storagethr',
#        'timescale_y', 'exploredpatterns', 'exploredpatterns2', 'accmlen',
#        'accmcrd', 'accmsup', 'semf_y'],
#       dtype='object')

# %%
df3 = df3[['minsup', 'time(ms)_x', 'time(ms)_y', 'nitemsets_x', 'nitemsets_y']]
df3['time(ms)_x'] = df3['time(ms)_x'] / 1000
df3['time(ms)_y'] = df3['time(ms)_y'] / 1000
df3
# Out:
# /home/mfrancia/ctm/src/main/python/CTM/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/mfrancia/ctm/src/main/python/CTM/venv/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    minsup  time(ms)_x  time(ms)_y  nitemsets_x  nitemsets_y
# 0      20     293.507     222.530    240828256          853
# ...

# %%
df3.rename(columns={'time(ms)_x': 'PFPGrowth', 'time(ms)_y': 'CTM'}).plot(x='minsup', y=['CTM', 'PFPGrowth'], logy=True)
# Out:
# <AxesSubplot:xlabel='minsup'>

# %%
df3.rename(columns={'nitemsets_x': 'PFPGrowth', 'nitemsets_y': 'CTM', }).plot(x='minsup', y=['CTM', 'PFPGrowth'], logy=True)
# Out:
# <AxesSubplot:xlabel='minsup'>
